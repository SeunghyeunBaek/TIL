# %%
# lib
import requests # get url respoonse
import bs4 # response to bs4 object
import time # delay 1 sec for each page
import pandas as pd # data to csv

import matplotlib.pyplot as plt
import seaborn as sb
import re

# %%
# 접속할 페이지 주소 : 소스보기 -> iframe 검색 ->src, 영화 캡틴마블(2019) 영화 평점 데이터
site = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=132623&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

# site to soup
soup = requestPage(site)
data = []
# 전체 페이지수를 가져온다.
tot_page_cnt = getPageCnt()
# 페이지 0~3010 : 총 30100 개, 페이지당 댓글 10개
for idx in range(15):
    print(f'{idx+1}/10')
    print('='*100)
    url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=132623&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page={idx+1}'
    data.append(getResult_2(requestPage(url)))
    time.sleep(1)
df_res = pd.concat(data, ignore_index=True)
#df.to_csv('naver_satar_data.csv',index = False, encoding = 'utf-8-sig',moded = 'a')
# Out:
# 1/10
# ====================================================================================================
# 2/10
# ====================================================================================================
# 3/10
# ====================================================================================================
# 4/10
# ====================================================================================================
# 5/10
# ====================================================================================================
# 6/10
# ====================================================================================================
# 7/10
# ====================================================================================================
# 8/10
# ====================================================================================================
# 9/10
# ====================================================================================================
# 10/10
# ====================================================================================================
# 11/10
# ====================================================================================================
# 12/10
# ====================================================================================================
# 13/10
# ====================================================================================================
# 14/10
# ====================================================================================================
# 15/10
# ====================================================================================================
#                            id  score  up_vote  down_vote  \
# 0              눈누난나(park****)     10     7129       3427
# 1               이지섭(kfco****)     10     6418       3066
# 2             요염한탱자(pure****)      6     9057       6147
# 3                유범(dbqj****)     10     5216       2554
# 4               서창원(seog****)      9     4223       1695
# 5                수빈(4220****)      9     4309       1862
# 6    040614 대구중 박재호(wjse****)      5     6325       3969
# 7              별명없음(mimk****)     10     3458       1659
# 8                어머(sabi****)     10     2943       1380
# 9             정아르퀴임(kimj****)     10     2782       1242
# 10                   nabm****     10     2426       1050
# 11              수돗물(dbtj****)      9     2097        862
# 12             구름사탕(joj2****)     10     1951        821
# 13              이소리(napu****)     10     1716        658
# 14                오(harn****)      2     4707       3816
# 15              곽경민(wedu****)     10     1539        654
# 16              SAY(aaa7****)     10     1512        684
# 17             무한괘도(oana****)      1     6673       5901
# 18                   hyun****      1     4479       3719
# 19               루트(ratt****)      1     4698       3960
# 20                   leey****      1     3086       2429
# 21             1566(rlad****)     10     1212        645
# 22              소나무(lake****)      1     3159       2598
# 23                   tage****      2     4048       3489
# 24             어부바해(fdk1****)      3     1881       1323
# 25                   keia****      1     3328       2775
# 26               쪼윤(yuny****)      1     3371       2842
# 27          swim119(swim****)      1     3834       3307
# 28               열심(over****)      2     2190       1698
# 29               풍류(wks7****)      1     2264       1772
# ..                        ...    ...      ...        ...
# 120          바위오른무현(happ****)      1      610        565
# 121                  taun****     10      154        110
# 122           엠씨더맥스(8223****)      1      571        529
# 123             서혜민(shn4****)     10       64         23
# 124            유리쨔응(qlth****)     10       64         23
# 125             유지혜(zbfl****)     10       71         30
# 126            Blue(jehd****)      1      818        777
# 127              핑구(spin****)     10       54         14
# 128              하람(drla****)     10       68         28
# 129                  caco****     10       58         19
# 130            깐깐징어(gpfl****)     10       68         29
# 131            새벽그림(umso****)     10       55         18
# 132            홍홍아아(pooh****)     10       70         33
# 133         Ggyuwoo(wjdr****)      7       87         50
# 134              흐흐(tpdm****)     10       46         11
# 135           진격의봉순(thsx****)     10       53         18
# 136              윤샘(dbst****)     10       60         25
# 137             몰라요(scab****)      8       62         27
# 138                  tota****      1      490        455
# 139           포텐 경표(kp94****)      1      523        488
# 140             삼겹살(ahne****)     10       44         10
# 141             남예진(dpwl****)     10       42          9
# 142             박사장(pakp****)     10       43         10
# 143                  tktk****     10       44         11
# 144            Anya(choi****)     10       38          6
# 145                  soju****     10       41          9
# 146             레라초(wodl****)     10       43         11
# 147                  cptu****     10       44         12
# 148              이나(osy6****)     10       48         16
# 149              무명(non_****)     10       49         17
#
#                                                  reply
# 0    댓글보고 진짜 별론가 싶었는데 페미에 과잉반응 사람들이 난장판 쳐논거 같네요 재밌게...
# 1    이 영화를 페미라고 하는 사람들 논리로 보면 캡틴아메리카는 그럼 남성우월주의 영화로...
# 2                     알리타가 재미있다 공감 or 캡틴마블이 재미있다 비공감
# 3    ㅋㅋㅋ잼게보고옴 근데 좀 다들 기괴한거같음 ㅋㅋ 솔직히 브리라슨 이상의 실언을 하고...
# 4    정상인 남녀들은 아무렇지 않게 보고 나오는데 특정 남녀들만 죽으라고 싸우는 중. 근...
# 5    재밌기만 한데 뭘 ㅋㅋ 캡틴 마블 다 거른다면서개봉 첫날부터 부랴 부랴 댓글 남기는...
# 6    여성히어로는 원더우먼이 더 멋진거 같음.그리고 페미도 페미지만 고인모독은 진짜 좀 ...
# 7    솔직히 1점주는 애들은 보지도않고 그냥 브리라슨자체를 싫어하는 애들이고. 객관적으로...
# 8    주위남자들 불매한단소리 1도없음ㅋㅋ 여기서 댓글쓰고 추천 누르는 애들 하타취 찐따 ...
# 9        잘만들었구만~~~페미는 다른 배우들도 다 언급했는데,얘만 물어뜯는 이유좀.;;
# 10                              굿 재밌어요 방금봄 평범테러 믿지마셈
# 11   단독히어로영화중에서 가장 숙제가 많은 영화인데도 스토리를 잘짠것같음 연결고리도 짜임...
# 12   왜 다들  평점 낮게 주는지 노이해,,, 나도 첨에 평점 보고 볼지말지 고민하다 쿠...
# 13   히어로의 성별을 꼭 갈라야됨? 여성이든 남성이든 다 같은 히어로구만 영화도 안 본 ...
# 14   관람객재미없음. 마블 특유의 원테이크 액션신 없음. 유머도 마블스럽지 않음. 이거 ...
# 138                              알리타 보다 영화적 매력 떨어집니다
# 139                                    마블의 유일한 실수...
# 140                                     너무재밌어요 감동적 ㅜ
# 141  영화 전개랑 웃음 요소, 비판 요소를 구분 못하는 사람들 후기는 볼 필요 없고 보고...
# 142                      개존잼 진짜 넋놓고 봤다 쿠키무조건 바야함 ㅎㄷㄷ
# 143                                    재밋어요 짱멋잇음 ㅜㅠㅠ
# 144  그남들 평점테러 존웃ㅋㅋ여윽시 돈 안드는 일은 제일 잘하죠? 그렇게 쿵쾅대더니 불매...
# 145                          오~나의  새로운 캡틴! 캐롤 댄버스!!♡
# 146                                최고의 마블영화 시원시원한 액선
# 147                  지금까지 이런 쎈캐는 없었다. 멋지고 까리하고 다 해먹음
# 148                                  관람객최고ㅜㅜ 당신이 나의빛
# 149                                    재밌고 유익하고 최고였다
#
# [150 rows x 5 columns]

# %%
df_res['ud_ratio']=df_res.up_vote/df_res.down_vote

# %%
fig, ax = plt.subplots(1,4,figsize = (15,4))
sb.distplot(df_res.score,ax=ax[0])
sb.distplot(df_res.up_vote,ax=ax[1])
sb.distplot(df_res.down_vote,ax=ax[2])
sb.distplot(df_res.ud_ratio,ax=ax[3])
plt.show()

# %%
fig,ax  = plt.subplots(figsize=(15,8))
corr = df_res.corr()
sb.heatmap(corr,cmap='coolwarm')

# %%
# url 받아서 bs4 객체를 반환하는 함수
# xlml 파서를 쓰면 tag 방식을 쓰는 모든 문서 타입에 적용할 수 있다.
def requestPage(url):
    response = requests.get(url)
    soup = bs4.BeautifulSoup(response.text, 'lxml')
    return soup

# %%
# 필요한 정보를 가져온다.
def getResult_2(soup):  
    
    #해당 페이지의 댓글 ,id, 평점, up_vote, down_vote 을 가져온다.
    reply_list = soup.select('div.score_result li div.score_reple>p')
    id_list = soup.select('div.score_result li div.score_reple>dl>dt>em>a>span')
    score_list = soup.select('div.score_result li div.star_score em')
    up_vote_list = soup.select('div.score_result li div.btn_area>strong:nth-child(2) > span')
    down_vote_list  = soup.select('div.score_result li div.btn_area> strong:nth-child(4)> span')
    result = []
    for li in [score_list,up_vote_list,down_vote_list]:
        result.append([int(re.sub(',','',tag.text)) for tag in li])
    for li in [id_list,reply_list]:
        result.append([tag.text for tag in li])
    res = pd.DataFrame({'id':result[3],'score':result[0],'up_vote':result[1],'down_vote':result[2],'reply': result[4]})
    return res

# %%
# 전체 페이지 개수를 반환하는 함수
def getPageCnt():
    #접속할 페이지 주소
    url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=132623&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'
    res = requests.get(url)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    cnt = soup.select('div.score_total>strong.total>em')[0].text
    cnt = int(re.sub(r',','',cnt))
    
    # 한 페이지당 댓글이 10개다.
    if cnt%10 > 0:
        cnt = cnt +1
    return cnt//10
