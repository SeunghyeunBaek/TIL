# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Functions</a></span></li></ul></div>

# %%
import requests
import bs4
import json
import time
import pandas as pd

# %%
url1= 'https://maps.googleapis.com/maps/api/place/nearbysearch/xml'
url2= 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# %%
# Prameters
params={
    'key':'AIzaSyB9OiFb_pYHxQF0B_kZKTCQJeAOZWjeNZ4',
    'location':'37.5161071,127.1004473',
    'radius':'500',
    'language':'ko',
    'type':'cafe'
}

# %%
res_xml = connectionXML(url1,params) # XML 데이터를 가져온다.
res_json = connectionJSON(url2,params) # Json 데이터를 가져온다.

# Status
status_xml = res_xml.find('status').text.strip() # 'OK'
status_json = res_json['status'] # 'OK'

# .csv 파일로 저장헀는지 여부를 알기위한 변수
chk = False

# %%
if status_xml == 'OK':
    res_dict_xml = getDataXml(res_xml)
chk = False
# Out:
# 저장완료

# %%
if status_json == 'OK':
    res_dict_json = getDataJson(res_json)
chk = False
# Out:
# {'name': ['엔제리너스 잠실역점'], 'vicinity': ['송파구 신천동 7-18'], 'latitude': [37.5144045], 'logitude': [127.100709]}
# ====================================================================================================
# {'name': ['엔제리너스 잠실역점', '카페네스카페 신천TS점'], 'vicinity': ['송파구 신천동 7-18', '송파구 잠실6동 7-23'], 'latitude': [37.5144045, 37.515377], 'logitude': [127.100709, 127.103514]}
# ====================================================================================================
# {'name': ['엔제리너스 잠실역점', '카페네스카페 신천TS점', '죠샌드위치앤커피'], 'vicinity': ['송파구 신천동 7-18', '송파구 잠실6동 7-23', '송파구 신천동 7-14'], 'latitude': [37.5144045, 37.515377, 37.516932], 'logitude': [127.100709, 127.103514, 127.1022921]}
# ====================================================================================================
# {'name': ['엔제리너스 잠실역점', '카페네스카페 신천TS점', '죠샌드위치앤커피', '스타벅스 잠실역점'], 'vicinity': ['송파구 신천동 7-18', '송파구 잠실6동 7-23', '송파구 신천동 7-14', '송파구 송파대로 562'], 'latitude': [37.5144045, 37.515377, 37.516932, 37.515287], 'logitude': [127.100709, 127.103514, 127.1022921, 127.099234]}
# ====================================================================================================
# {'name': ['엔제리너스 잠실역점', '카페네스카페 신천TS점', '죠샌드위치앤커피', '스타벅스 잠실역점', '바운스트램폴린파크 잠실점'], 'vicinity': ['송파구 신천동 7-18', '송파구 잠실6동 7-23', '송파구 신천동 7-14', '송파구 송파대로 562', '타워730 지하1층 6호, Songpa-gu'], 'latitude': [37.5144045, 37.515377, 37.516932, 37.515287, 37.515701], 'logitude': [127.100709, 127.103514, 127.1022921, 127.099234, 127.098872]}
# ====================================================================================================
# {'name': ['엔제리너스 잠실역점', '카페네스카페 신천TS점', '죠샌드위치앤커피', '스타벅스 잠실역점', '바운스트램폴린파크 잠실점', '할리스커피'], 'vicinity': ['송파구 신천동 7-18', '송파구 잠실6동 7-23', '송파구 신천동 7-14', '송파구 송파대로 562', '타워730 지하1층 6호, Songpa-gu', '송파구 올림픽로 319'], 'latitude': [37.5144045, 37.515377, 37.516932, 37.515287, 37.515701, 37.5157377], 'logitude': [127.100709, 127.103514, 127.1022921, 127.099234, 127.098872, 127.1055141]}
# ====================================================================================================
'송파구 잠실동 40-1', '송파구 잠실6동 올림픽로 300', '송파구 신천로', '송파구 신천동 7-11', '송파구 올림픽로35길 141', '장미이파트 에이상가 2동 109호, 124 올림픽로35길, 송파구', '신천동 A 잠실더샵스타파크', '송파구 신천동', '송파구 잠실6동 신천로2길 32', '신천동 7-18번지 롯데캐슬골드 송파구 서울특별시 KR', '송파구 신천동 7-12 홈플러스 잠실점'], 'latitude': [37.5144045, 37.515377, 37.516932, 37.515287, 37.515701, 37.5157377, 37.5175312, 37.5175312, 37.5188607, 37.512127, 37.51398320000001, 37.5166532, 37.5160383, 37.5155153, 37.5174755, 37.5171257, 37.516802, 37.514885, 37.5143367, 37.51632110000001], 'logitude': [127.100709, 127.103514, 127.1022921, 127.099234, 127.098872, 127.1055141, 127.103575, 127.103575, 127.0992536, 127.0993481, 127.1050344, 127.1009025, 127.0995356, 127.0989279, 127.101109, 127.1020148, 127.102385, 127.1019402, 127.1005715, 127.1031572]}
# ====================================================================================================
# 저장완료

# %% [markdown]
# # Functions

# %%
def connectionXML(url,params):
    res = requests.get(url,params = params)
    soup = bs4.BeautifulSoup(res.text,'lxml')
    return soup

# %%
def connectionJSON(url,params):
    res = requests.get(url,params = params)
    json_obj = json.loads(res.text)
    return json_obj

# %%
def getDataXml(res_xml):
    
    # 데이터를 담는 dictionary
    dat_dict = {'name':[],'vicinity':[],'latitude':[],'logitude':[]}
    
    # result 태그를 가져온다.
    result_list = res_xml.find_all('result')
    
    # 태그의 수 만큼 반복.
    for res_tag in result_list:
        name_str = res_tag.find('name').text.strip() # name 을 가져온다.
        vicinity_str = res_tag.find('vicinity').text.strip() # vincinity 를 가져온다.
        
        #위도와 경도를 가져온다.
        geom_tag = res_tag.find('geometry')
        loc_tag = geom_tag.find('location')
        lat_str = loc_tag.find('lat').text.strip()
        lng_str = loc_tag.find('lng').text.strip()
        
        # dictionary 에 저장한다.
        dat_dict['name'].append(name_str)
        dat_dict['vicinity'].append(vicinity_str)
        dat_dict['latitude'].append(lat_str)
        dat_dict['logitude'].append(lng_str)
    
    df = pd.DataFrame.from_dict(dat_dict)
    
    global chk
    
    if chk == False:
        chk = True
        df.to_csv(r'google_api.csv',index = False,encoding = 'utf-8-sig')
    else :
        df.to_csv(r'google_api.csv',index = False,encoding = 'utg-8-sig',header = False, mode = 'a')
    
    print('저장완료')

    return df

# %%
def getDataJson(res_json):

    # 데이터를 담는 dictionary
    dat_dict = {'name':[],'vicinity':[],'latitude':[],'logitude':[]}
    
    res_list = res_json['results']
    
    for res in res_list:
        name_str = res['name'].strip()
        vicinity_str  = res['vicinity'].strip()
        lat_str = res['geometry']['location']['lat']
        lng_str = res['geometry']['location']['lng']
        
        # dictionary 에 저장한다.
        dat_dict['name'].append(name_str)
        dat_dict['vicinity'].append(vicinity_str)
        dat_dict['latitude'].append(lat_str)
        dat_dict['logitude'].append(lng_str)
    
    df = pd.DataFrame.from_dict(dat_dict)
    
    global chk
    
    if chk == False:
        chk = True
        df.to_csv(r'google_api_json.csv',index = False,encoding = 'utf-8-sig')
    else :
        df.to_csv(r'google_api_json.csv',index = False,encoding = 'utg-8-sig',header = False, mode = 'a')
    
    print('저장완료')

    return df
